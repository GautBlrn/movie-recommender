# %% [markdown]
# ## Exploration du dataframe

# %%
import pandas as pd
from pathlib import Path

# Chemin robuste : notebook dans /notebooks
DATA_PATH = Path("data/raw/movie_metadata.csv")
# Out:
#      <input type="file" id="files-2357eda2-407e-4198-ba22-ace4bf76de6e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2357eda2-407e-4198-ba22-ace4bf76de6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('DATA_PATH')

# %%
df.head()
# Out:
#    color                                movie_title      director_name  \
# 0  Color                                    Avatar       James Cameron
# 1  Color  Pirates of the Caribbean: At World's End      Gore Verbinski
# 2  Color                                   Spectre          Sam Mendes
# 3  Color                     The Dark Knight Rises   Christopher Nolan
# 4  Color                               John Carter      Andrew Stanton
#
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                   462.0     132.0                    475.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# ...

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.isna().sum()
# Out:
# color                         17
# movie_title                    1
# director_name                105
# num_critic_for_reviews        50
# duration                      16
# director_facebook_likes      105
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         8
# gross                        884
# genres                         1
# actor_1_name                   8
# num_voted_users                1
# cast_total_facebook_likes      1
# actor_3_name                  23
# facenumber_in_poster          14
# plot_keywords                153
# movie_imdb_link                1
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     1
# aspect_ratio                 329
# movie_facebook_likes           1
# dtype: int64

# %% [markdown]
# ### On vérifie les durées en dessous de 60 minutes

# %%
df_check = df.loc[df['duration'] < 60]

# %%
df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])
# Out:
# /tmp/ipython-input-2791782956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])

# %%
df_check[['movie_title', 'movie_imdb_link']]
# Out:
#                                             movie_title  \
# 395                                           Hannibal
# 524                                        Constantine
# 530                                               Life
# 580                                      Sleepy Hollow
# 631                                  Last Man Standing
# ...                                                 ...
# 4844                                     McHale's Navy
# 4862                                  The Honeymooners
# 5018                               The Call of Cthulhu
# 5026                                         Daredevil
# 5032  Alpha and Omega 4: The Legend of the Saw Tooth...
#
#                           movie_imdb_link
# 395   http://www.imdb.com/title/tt2243973
# 524   http://www.imdb.com/title/tt3489184
# 530   http://www.imdb.com/title/tt0874936
# 580   http://www.imdb.com/title/tt2647544
# 631   http://www.imdb.com/title/tt1828327
# ...                                   ...
# ...

# %%
to_del = [279,404,459,479,537,543,593,645,757,816,826,833,857,962,1023,1133,1175,1265,1404, 620,1664,1736,1802,1818,1842\
          ,1947,1972,2075,2191,2241,2257,2303,2342,2370,2412,2594,2609,2824,2828,2952,3084,3174,3207,3303,3329,3481,3490,\
          3579,3623,3661,3807,3847,3951,3982,3989,4015,4079,4115,4281,4327,4482,4634,4803,4819,4869,5039]

# %% [markdown]
# ### On vérifie les durées au dessus de 3 heures

# %%
df_check = df.loc[df['duration'] > 240]

# %%
df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])
# Out:
# /tmp/ipython-input-2791782956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])

# %%
df_check[['movie_title', 'movie_imdb_link']]
# Out:
#                        movie_title                      movie_imdb_link
# 860             Gods and Generals   http://www.imdb.com/title/tt0279111
# 1113                Heaven's Gate   http://www.imdb.com/title/tt0080855
# 1129                    Cleopatra   http://www.imdb.com/title/tt0056937
# 1457          Blood In, Blood Out   http://www.imdb.com/title/tt0106469
# 1524               Apocalypse Now   http://www.imdb.com/title/tt0078788
# 1661                      Trapped   http://www.imdb.com/title/tt3561180
# 1665  Once Upon a Time in America   http://www.imdb.com/title/tt0087843
# 1923                   Gettysburg   http://www.imdb.com/title/tt0107007
# 2393                       Carlos   http://www.imdb.com/title/tt1321865
# 2485      Arn: The Knight Templar   http://www.imdb.com/title/tt0837106
# 2648                  The Company   http://www.imdb.com/title/tt0488352
# 2882                     Das Boot   http://www.imdb.com/title/tt0082096
# ...

# %%
to_del2 = [1710, 2466, 2727]

# %% [markdown]
# ### On vérifie les durées nulles

# %%
df_check = df.loc[df['duration'].isnull()]

# %%
df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])
# Out:
# /tmp/ipython-input-2791782956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])

# %%
df_check[['movie_title', 'movie_imdb_link']]
# Out:
#                                          movie_title  \
# 196   Harry Potter and the Deathly Hallows: Part II
# 203    Harry Potter and the Deathly Hallows: Part I
# 1465                            Black Water Transit
# 3496                                    War & Peace
# 3697                           Should've Been Romeo
# 3716                                          Barfi
# 4146                         Hum To Mohabbat Karega
# 4227                                       N-Secure
# 4232                            Dil Jo Bhi Kahey...
# 4340                                     Wolf Creek
# 4427                              Karachi se Lahore
# 4503                                        Destiny
# 4735                               Romantic Schemer
# 4768                                  The Naked Ape
# 5024     Star Wars: Episode VII - The Force Awakens
# 5025                                             NaN
#
#                           movie_imdb_link
# ...

# %%
to_del3 = [3604, 4517, 4690]

# %%
# Suppression lignes inutiles
df = df.drop(to_del + to_del2 + to_del3)

# %% [markdown]
# ### On remplace les durées manquantes

# %%
df_replace = df.loc[df['duration'].isnull()]
df_replace
# Out:
#       color                                     movie_title  \
# 196   Color  Harry Potter and the Deathly Hallows: Part II
# 203   Color   Harry Potter and the Deathly Hallows: Part I
# 1465  Color                            Black Water Transit
# 3496  Color                                    War & Peace
# 3697  Color                           Should've Been Romeo
# 3716  Color                                          Barfi
# 4146  Color                         Hum To Mohabbat Karega
# 4227  Color                                       N-Secure
# 4232  Color                            Dil Jo Bhi Kahey...
# 4340  Color                                     Wolf Creek
# 4427  Color                              Karachi se Lahore
# 4503  Color                                        Destiny
# 4735  Color                               Romantic Schemer
# 4768  Color                                  The Naked Ape
# 5024  Color     Star Wars: Episode VII - The Force Awakens
# ...

# %%
df.at[4, 'duration'] = 138
df.at[199, 'duration'] = 130
df.at[206, 'duration'] = 146
df.at[1510, 'duration'] = 100
df.at[3815, 'duration'] = 120
df.at[3834, 'duration'] = 105
df.at[4299, 'duration'] = 153
df.at[4392, 'duration'] = 105
df.at[4397, 'duration'] = 144
df.at[4609, 'duration'] = 143
df.at[4948, 'duration'] = 84
df.at[4989, 'duration'] = 100

# %% [markdown]
# ### On vérifie les dates de sorties nulles

# %%
df_check = df.loc[df['title_year'].isnull()]

# %%
df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])
# Out:
# /tmp/ipython-input-2791782956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])

# %%
df_check[['movie_title', 'movie_imdb_link']]
# Out:
#                                       movie_title  \
# 174                                   Miami Vice
# 256                                   The A-Team
# 395                                     Hannibal
# 524                                  Constantine
# 530                                         Life
# ...                                           ...
# 4862                            The Honeymooners
# 5024  Star Wars: Episode VII - The Force Awakens
# 5025                                          NaN
# 5026                                   Daredevil
# 5029                               Unforgettable
#
#                           movie_imdb_link
# 174   http://www.imdb.com/title/tt0086759
# 256   http://www.imdb.com/title/tt0084967
# 395   http://www.imdb.com/title/tt2243973
# 524   http://www.imdb.com/title/tt3489184
# 530   http://www.imdb.com/title/tt0874936
# ...                                   ...
# 4862  http://www.imdb.com/title/tt0042114
# ...

# %%
to_del4 = [177,260,685,994,1007,1035,1346,1444,1499,1620,1659,2143,2459,2552,2702,2765,2775,2870,3376,3397,3419,\
           3507,3509,3650,3800,3871,3881,3900,4087,4113,4119,4249,4288,4304,4460,4467,4798]

# %%
# Suppression des lignes inutiles

df = df.drop(to_del4)

# %% [markdown]
# ### On remplace les languages manquants

# %%
df_check = df.loc[df['language'].isnull()]

# %%
df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])
# Out:
# /tmp/ipython-input-2791782956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_check['movie_imdb_link'] = df_check['movie_imdb_link'].map(lambda x: str(x)[:35])

# %%
df_check[['movie_title', 'movie_imdb_link']]
# Out:
#                                             movie_title  \
# 2812                                    Quest for Fire
# 2994                                    September Dawn
# 3751                                      Silent Movie
# 3810                                           Samsara
# 3978                                Love's Abiding Joy
# 4996  Intolerance: Love's Struggle Throughout the Ages
# 5002                                    The Big Parade
# 5013                    Over the Hill to the Poorhouse
# 5024        Star Wars: Episode VII - The Force Awakens
# 5025                                                NaN
# 5029                                     Unforgettable
# 5032  Alpha and Omega 4: The Legend of the Saw Tooth...
# 5038                              Kickboxer: Vengeance
# 5040                                       A Fine Step
#
#                           movie_imdb_link
# 2812  http://www.imdb.com/title/tt0082484
# 2994  http://www.imdb.com/title/tt0473700
# ...

# %%
df.at[4, 'language'] = 'English'
df.at[3086, 'language'] = 'English'
df.at[3539, 'language'] = 'English'
df.at[3869, 'language'] = 'English'
df.at[4110, 'language'] = 'English'
df.at[4409, 'language'] = 'English'
df.at[4630, 'language'] = 'English'
df.at[4810, 'language'] = 'English'
df.at[4885, 'language'] = 'English'
df.at[4958, 'language'] = 'English'

# %% [markdown]
# ### Les pays et couleurs manquants ont été fait sur le excel

# %% [markdown]
# ## Check

# %%
df.isna().sum()
# Out:
# color                         16
# movie_title                    1
# director_name                104
# num_critic_for_reviews        49
# duration                      16
# director_facebook_likes      104
# actor_3_facebook_likes        21
# actor_2_name                  12
# actor_1_facebook_likes         7
# gross                        871
# genres                         1
# actor_1_name                   7
# num_voted_users                1
# cast_total_facebook_likes      1
# actor_3_name                  21
# facenumber_in_poster          13
# plot_keywords                149
# movie_imdb_link                1
# num_user_for_reviews          20
# language                      14
# country                        4
# content_rating               300
# budget                       484
# title_year                   107
# actor_2_facebook_likes        12
# imdb_score                     1
# aspect_ratio                 321
# movie_facebook_likes           1
# dtype: int64

# %%
OUT_PATH = Path("../data/clean/movie_clean.csv")
OUT_PATH.parent.mkdir(parents=True, exist_ok=True)

df.to_csv(OUT_PATH, index=False)
print(f"Fichier sauvegardé : {OUT_PATH.resolve()}")

# %%
df.shape

# %%
df.duplicated().sum()
# Out:
# np.int64(42)

# %%
5043 - 4934
# Out:
# 109
